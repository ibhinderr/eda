# %%
#To import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

# %%
df = pd.read_csv(r'C:\Users\ASAD COMPUTERS\Desktop\Data Science\AtomCamp\M2\PYTHON\Project 4\zomato_restaurants_in_India.csv')
df.head()
# Out:
#     res_id                            name      establishment  \
# 0  3400299                     Bikanervala    ['Quick Bites']
# 1  3400005  Mama Chicken Mama Franky House    ['Quick Bites']
# 2  3401013                   Bhagat Halwai    ['Quick Bites']
# 3  3400290                   Bhagat Halwai    ['Quick Bites']
# 4  3401744     The Salt Cafe Kitchen & Bar  ['Casual Dining']
#
#                                                  url  \
# 0  https://www.zomato.com/agra/bikanervala-khanda...
# 1  https://www.zomato.com/agra/mama-chicken-mama-...
# 2  https://www.zomato.com/agra/bhagat-halwai-2-sh...
# 3  https://www.zomato.com/agra/bhagat-halwai-civi...
# 4  https://www.zomato.com/agra/the-salt-cafe-kitc...
#
#                                              address  city  city_id  \
# 0  Kalyani Point, Near Tulsi Cinema, Bypass Road,...  Agra       34
# 1        Main Market, Sadar Bazaar, Agra Cantt, Agra  Agra       34
# ...

# %%
#To read the last 5 rows of the given dataset.
df.tail()
# Out:
#           res_id                            name      establishment  \
# 211939   3202251  Kali Mirch Cafe And Restaurant  ['Casual Dining']
# 211940   3200996                      Raju Omlet    ['Quick Bites']
# 211941  18984164                The Grand Thakar  ['Casual Dining']
# 211942   3201138                          Subway    ['Quick Bites']
# 211943  18879846     Freshco's - The Health Cafe           ['Café']
#
#                                                       url  \
# 211939  https://www.zomato.com/vadodara/kali-mirch-caf...
# 211940  https://www.zomato.com/vadodara/raju-omlet-kar...
# 211941  https://www.zomato.com/vadodara/the-grand-thak...
# 211942  https://www.zomato.com/vadodara/subway-1-akota...
# 211943  https://www.zomato.com/vadodara/freshcos-the-h...
#
#                                                   address      city  city_id  \
# 211939  Manu Smriti Complex, Near Navrachna School, GI...  Vadodara       32
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 211944 entries, 0 to 211943
# Data columns (total 26 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   res_id                211944 non-null  int64
#  1   name                  211944 non-null  object
#  2   establishment         211944 non-null  object
#  3   url                   211944 non-null  object
#  4   address               211810 non-null  object
#  5   city                  211944 non-null  object
#  6   city_id               211944 non-null  int64
#  7   locality              211944 non-null  object
#  8   latitude              211944 non-null  float64
#  9   longitude             211944 non-null  float64
#  10  zipcode               48757 non-null   object
#  11  country_id            211944 non-null  int64
#  12  locality_verbose      211944 non-null  object
#  13  cuisines              210553 non-null  object
# ...

# %%
df.shape
# Out:
# (211944, 26)

# %%
df.size
# Out:
# 5510544

# %%
df.columns
# Out:
# Index(['res_id', 'name', 'establishment', 'url', 'address', 'city', 'city_id',
#        'locality', 'latitude', 'longitude', 'zipcode', 'country_id',
#        'locality_verbose', 'cuisines', 'timings', 'average_cost_for_two',
#        'price_range', 'currency', 'highlights', 'aggregate_rating',
#        'rating_text', 'votes', 'photo_count', 'opentable_support', 'delivery',
#        'takeaway'],
#       dtype='object')

# %%
df.describe()
# Out:
#              res_id        city_id       latitude      longitude  country_id  \
# count  2.119440e+05  211944.000000  211944.000000  211944.000000    211944.0
# mean   1.349411e+07    4746.785434      21.499758      77.615276         1.0
# std    7.883722e+06    5568.766386      22.781331       7.500104         0.0
# min    5.000000e+01       1.000000       0.000000       0.000000         1.0
# 25%    3.301027e+06      11.000000      15.496071      74.877961         1.0
# 50%    1.869573e+07      34.000000      22.514494      77.425971         1.0
# 75%    1.881297e+07   11306.000000      26.841667      80.219323         1.0
# max    1.915979e+07   11354.000000   10000.000000      91.832769         1.0
#
#        average_cost_for_two    price_range  aggregate_rating          votes  \
# count         211944.000000  211944.000000     211944.000000  211944.000000
# mean             595.812229       1.882535          3.395937     378.001864
# ...

# %%
df.describe(include='object')
# Out:
#                   name    establishment  \
# count           211944           211944
# unique           41100               27
# top     Domino's Pizza  ['Quick Bites']
# freq              3108            64390
#
#                                                       url  \
# count                                              211944
# unique                                              55568
# top     https://www.zomato.com/chennai/3bs-buddies-bar...
# freq                                                  169
#
#                                  address     city     locality zipcode  \
# count                             211810   211944       211944   48757
# unique                             50657       99         3731    1311
# top     Laxman Jhula, Tapovan, Rishikesh  Chennai  Civil Lines       0
# freq                                 299    11630         3660    7100
#
#              locality_verbose      cuisines         timings currency  \
# ...

# %% [markdown]
# ## Duplicate Data Handling

# %%
df.duplicated().sum()
# Out:
# 151527

# %%
# df_1 is copied to make further amendments.
df_1 = df.copy()
df_1.head(2)
# Out:
#     res_id                            name    establishment  \
# 0  3400299                     Bikanervala  ['Quick Bites']
# 1  3400005  Mama Chicken Mama Franky House  ['Quick Bites']
#
#                                                  url  \
# 0  https://www.zomato.com/agra/bikanervala-khanda...
# 1  https://www.zomato.com/agra/mama-chicken-mama-...
#
#                                              address  city  city_id  \
# 0  Kalyani Point, Near Tulsi Cinema, Bypass Road,...  Agra       34
# 1        Main Market, Sadar Bazaar, Agra Cantt, Agra  Agra       34
#
#      locality   latitude  longitude  ... price_range  currency  \
# 0    Khandari  27.211450  78.002381  ...           2       Rs.
# 1  Agra Cantt  27.160569  78.011583  ...           2       Rs.
#
#                                           highlights aggregate_rating  \
# 0  ['Lunch', 'Takeaway Available', 'Credit Card',...              4.4
# 1  ['Delivery', 'No Alcohol Available', 'Dinner',...              4.4
#
# ...

# %%
#deleting the Duplicate records.
df_1 = df_1.drop_duplicates(keep='first')
df_1
# Out:
#           res_id                            name        establishment  \
# 0        3400299                     Bikanervala      ['Quick Bites']
# 1        3400005  Mama Chicken Mama Franky House      ['Quick Bites']
# 2        3401013                   Bhagat Halwai      ['Quick Bites']
# 3        3400290                   Bhagat Halwai      ['Quick Bites']
# 4        3401744     The Salt Cafe Kitchen & Bar    ['Casual Dining']
# ...          ...                             ...                  ...
# 211882  19142822           Shree Janta Ice Cream  ['Dessert Parlour']
# 211925  18984164                The Grand Thakar    ['Casual Dining']
# 211926  18019952                     Geeta lodge    ['Casual Dining']
# 211940   3200996                      Raju Omlet      ['Quick Bites']
# 211942   3201138                          Subway      ['Quick Bites']
#
#                                                       url  \
# 0       https://www.zomato.com/agra/bikanervala-khanda...
# ...

# %% [markdown]
# ## Handling Missing Values

# %%
df_1.isna().sum()
# Out:
# res_id                      0
# name                        0
# establishment               0
# url                         0
# address                    18
# city                        0
# city_id                     0
# locality                    0
# latitude                    0
# longitude                   0
# zipcode                 47869
# country_id                  0
# locality_verbose            0
# cuisines                  470
# timings                  1070
# average_cost_for_two        0
# price_range                 0
# currency                    0
# highlights                  0
# aggregate_rating            0
# rating_text                 0
# votes                       0
# photo_count                 0
# opentable_support          19
# delivery                    0
# takeaway                    0
# dtype: int64

# %% [markdown]
# <p><b>To find missing values percentage.</b></p>

# %%
print('Amount of missing values in %age :- ')
for column in df_1.columns:
    percentage_missing = np.mean(df_1[column].isna())
    print(f'{column}: {percentage_missing*100:.2f}%')
# Out:
# Amount of missing values in %age :-
# res_id: 0.00%
# name: 0.00%
# establishment: 0.00%
# url: 0.00%
# address: 0.03%
# city: 0.00%
# city_id: 0.00%
# locality: 0.00%
# latitude: 0.00%
# longitude: 0.00%
# zipcode: 79.23%
# country_id: 0.00%
# locality_verbose: 0.00%
# cuisines: 0.78%
# timings: 1.77%
# average_cost_for_two: 0.00%
# price_range: 0.00%
# currency: 0.00%
# highlights: 0.00%
# aggregate_rating: 0.00%
# rating_text: 0.00%
# votes: 0.00%
# photo_count: 0.00%
# opentable_support: 0.03%
# delivery: 0.00%
# takeaway: 0.00%

# %% [markdown]
# ## Missing Values Imputation

# %%
#for Zipcode
df_1.drop(['zipcode'],axis=1,inplace=True)

# %%
df_2 = df_1.copy()
df_2.head(2)
# Out:
#     res_id                            name    establishment  \
# 0  3400299                     Bikanervala  ['Quick Bites']
# 1  3400005  Mama Chicken Mama Franky House  ['Quick Bites']
#
#                                                  url  \
# 0  https://www.zomato.com/agra/bikanervala-khanda...
# 1  https://www.zomato.com/agra/mama-chicken-mama-...
#
#                                              address  city  city_id  \
# 0  Kalyani Point, Near Tulsi Cinema, Bypass Road,...  Agra       34
# 1        Main Market, Sadar Bazaar, Agra Cantt, Agra  Agra       34
#
#      locality   latitude  longitude  ...  price_range currency  \
# 0    Khandari  27.211450  78.002381  ...            2      Rs.
# 1  Agra Cantt  27.160569  78.011583  ...            2      Rs.
#
#                                           highlights aggregate_rating  \
# 0  ['Lunch', 'Takeaway Available', 'Credit Card',...              4.4
# 1  ['Delivery', 'No Alcohol Available', 'Dinner',...              4.4
#
# ...

# %%
#For opentable_support column.
df_2.drop(['opentable_support'], axis=1, inplace = True)

# %%
# !pip install geopy

# %%
#For address column
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter
# Creating a geocoder object with a higher timeout
geolocator = Nominatim(user_agent="restaurant_geocoder", timeout=10)
# Function to get address from latitude and longitude
def get_address(lat, lon):
    location = geolocator.reverse((lat, lon))
    return location.address if location else None

# Assuming df is your DataFrame and 'latitude', 'longitude', and 'address' are column names
# Fill missing addresses based on latitude and longitude
df_2['address'] = df_2.apply(lambda row: row['address'] if pd.notnull(row['address']) else get_address(row['latitude'], row['longitude']), axis=1)

# %%
#For timings column.
df_2['timings'] = df_2['timings'].fillna('Not Available')

# %%
#For cuisines column.
df_2['cuisines']=df_2['cuisines'].fillna('Not Available')

# %%
df_2.isna().sum()
# Out:
# res_id                  0
# name                    0
# establishment           0
# url                     0
# address                 0
# city                    0
# city_id                 0
# locality                0
# latitude                0
# longitude               0
# country_id              0
# locality_verbose        0
# cuisines                0
# timings                 0
# average_cost_for_two    0
# price_range             0
# currency                0
# highlights              0
# aggregate_rating        0
# rating_text             0
# votes                   0
# photo_count             0
# delivery                0
# takeaway                0
# dtype: int64

# %% [markdown]
# ## Handling Data Type Inconcistencies

# %%
# transforming negative to positive values
df_2['votes'] = df_2['votes'].abs()

# %%
df_2['votes'].describe()
# Out:
# count    60417.000000
# mean       261.575583
# std        728.283944
# min          0.000000
# 25%          7.000000
# 50%         42.000000
# 75%        207.000000
# max      42539.000000
# Name: votes, dtype: float64

# %%
#transforming 'â€“' to'to'
df_2['timings']=df_2['timings'].str.replace('â€“','to',regex=False)

# %%
df_2['timings'].head(100)
# Out:
# 0                            8:30am – 10:30pm (Mon-Sun)
# 1     12:30PM to 12Midnight (Mon, Wed, Thu, Fri, Sat...
# 2                                      9:30 AM to 11 PM
# 3                                  8am – 11pm (Mon-Sun)
# 4                                  11:30 AM to 11:30 PM
#                             ...
# 95                              12noon – 11pm (Mon-Sun)
# 96    12:30pm – 10:30pm (Mon-Thu),12:30pm – 10:45pm ...
# 97                                  8 AM to 12 Midnight
# 98                                        9 AM to 11 PM
# 99                                11am – 10pm (Mon-Sun)
# Name: timings, Length: 100, dtype: object

# %% [markdown]
# ## Data Distribution

# %%
# Storing numerical columns in a variable
numeric_df = df_2.select_dtypes(include=['number'])
numeric_df.columns
# Out:
# Index(['res_id', 'city_id', 'latitude', 'longitude', 'country_id',
#        'average_cost_for_two', 'price_range', 'aggregate_rating', 'votes',
#        'photo_count', 'delivery', 'takeaway'],
#       dtype='object')

# %%
# Plotting correlation matrix
correlation = numeric_df.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ## Distribution of Numerical Columns

# %%
#For 'average_cost_for_two'.
plt.figure(figsize=(8,6))
sns.histplot(df_2['average_cost_for_two'],bins=30,kde=True)
plt.title('Distribution of average_cost_for_two')
plt.xlabel('average_cost_for_two')
plt.ylabel('frequency')
plt.show()

# %%
#For 'price_range'.
plt.figure(figsize=(8,6))

sns.histplot(df_2['price_range'],bins=30,kde=True)
plt.title('Distribution of price_range')
plt.xlabel('price_range')
plt.ylabel('frequency')
plt.show()

# %%
#For 'aggregate_rating'.
plt.figure(figsize=(8,6))

sns.histplot(df_2['aggregate_rating'],bins=30,kde=True)
plt.title('Distribution of aggregate_rating')
plt.xlabel('aggregate_rating')
plt.ylabel('frequency')
plt.show()

# %%
#For 'votes'.
plt.figure(figsize=(8,6))

sns.histplot(df_2['votes'],bins=30,kde=True)
plt.title('Distribution of Votes')
plt.xlabel('votes')
plt.ylabel('frequency')
plt.show()

# %%
#For 'photo_count'.
plt.figure(figsize=(8,6))

sns.histplot(df_2['photo_count'],bins=30,kde=True)
plt.title('Distribution of photo_count')
plt.xlabel('photo_count')
plt.ylabel('frequency')
plt.show()

# %%
#For City Distribution.
top_n = 10
city_cat = df_2['city'].value_counts()[:top_n]
plt.figure(figsize=(8,6))
plt.bar(city_cat.index,city_cat.values)
plt.xticks(rotation=90)
plt.title('Distribution of City (Top 10)')
plt.xlabel('City')
plt.ylabel('frequency')
plt.show()

# %%
#For Cuisines Distribution.
top_n = 10
cuisines_cat = df_2['cuisines'].value_counts()[:top_n]
plt.bar(cuisines_cat.index,cuisines_cat.values)
plt.title('Distribution of Cuisines (Top-10)')
plt.xlabel('Cuisines')
plt.ylabel('Frequency')
plt.xticks(rotation=90)
plt.show()

# %%
#For Timings Distribution.
top_n = 10
timings_cat = df_2['timings'].value_counts()[:top_n]
plt.bar(timings_cat.index,timings_cat.values)
plt.title('Distribution of timings (Top-10)')
plt.xlabel('timings')
plt.ylabel('Frequency')
plt.xticks(rotation=90)
plt.show()

# %%
#For Highlights Distribution.
top_n = 10
highlights_cat = df_2['highlights'].value_counts()[:top_n]
plt.bar(highlights_cat.index,highlights_cat.values)
plt.title('Distribution of Highlights (Top-10)')
plt.xlabel('Highlights')
plt.ylabel('Frequency')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Regional Analysis

# %% [markdown]
# #### Compare the restaurant trends and customer preferences across different cities or regions in India.

# %%
# Top 10 Cities by Average Rating.
city_rating = df_2.groupby('city')['aggregate_rating'].mean().sort_values(ascending=False)
top_cities = city_rating.head(10)
print(top_cities)
#Plotting barplot
plt.figure(figsize=(8,6))
plt.bar(top_cities.index,top_cities.values)
plt.title('Top 10 cities by Average Rating')
plt.xlabel('Cities')
plt.ylabel('Average Rating')
plt.xticks(rotation=90)


plt.show()
# Out:
# city
# Gurgaon         3.872549
# Secunderabad    3.848454
# Mumbai          3.795863
# Hyderabad       3.775751
# New Delhi       3.770005
# Kolkata         3.767233
# Bangalore       3.729641
# Chennai         3.667764
# Noida           3.651648
# Navi Mumbai     3.546094
# Name: aggregate_rating, dtype: float64

# %%
# Top 10 Cities by 'average_cost_for_two'.
city_rat = df_1.groupby('city')['average_cost_for_two'].mean().sort_values(ascending=False)
top_city = city_rat.head(10)
print(top_city)
#plotting barplot
plt.bar(top_city.index,top_city.values)
plt.title('Top 10 Cities by Average Cost for Two')
plt.xlabel('City')
plt.ylabel('average_cost_for_two')
plt.xticks(rotation=45)

plt.show()
# Out:
# city
# Mumbai         1101.773050
# Gurgaon        1025.384615
# New Delhi      1018.305360
# Hyderabad       847.322171
# Bangalore       811.602537
# Goa             798.828058
# Noida           759.816850
# Pune            753.095238
# Navi Mumbai     752.382812
# Jaipur          716.222527
# Name: average_cost_for_two, dtype: float64

# %%
# Top 3 Cuisines in Top 5 Cities by Restaurants.
#Counting the number of restaurants for each 'cuisines' within each city. 
cities_agg = df_2.groupby(['city','cuisines'])['res_id'].size().reset_index(name='count')
#Finding top-3 cuisines in each city
top_cuisines = (cities_agg.groupby('city', as_index=False)
                            .apply(lambda x:x.nlargest(3,'count'))
                            .reset_index(drop=True))
# To find Top 5 cities
top_cities = cities_agg.groupby('city')['count'].sum().nlargest(5).index
# To filter 'top_cuisines' to include only top 5 cities
top_cuisines_cities = top_cuisines[top_cuisines['city'].isin(top_cities)]
# For Plotting
plot_data = (top_cuisines_cities
             .set_index(['city','cuisines'])
             .unstack('cuisines')['count']
             .fillna(0))
# Plotting the data
plot_data.plot(kind='bar',stacked=True,figsize=(10,7))
plt.title('Top 3 Cuisines in Top 5 Cities by Restaurants')
plt.xlabel('City')
plt.ylabel('Number of Restaurants')
plt.legend(title='cuisines',bbox_to_anchor=(1.0,1.0))
plt.xticks(rotation=90,ha='right')
plt.tight_layout()                                                               
plt.show()

# %% [markdown]
# #### Identify unique characteristics of the dining scene in each region.

# %%
#Finding Number of Cities in each city to observe dining scene in each region.
locality_establishments = df_2.groupby('city')['establishment'].size().sort_values(ascending=False)
top_locality = locality_establishments.head(5)
print(top_locality)
#plotting bargraph
plt.figure(figsize=(8,6))
plt.bar(top_locality.index,top_locality.values)
plt.title('Number of Top 5 Establishments across each City')
plt.xlabel('City')
plt.ylabel('Number of Establishment')
plt.xticks(rotation=45)
# Out:
# city
# Chennai      2612
# Mumbai       2538
# Bangalore    2365
# Pune         1911
# New Delhi    1847
# Name: establishment, dtype: int64
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'Chennai'),
#   Text(1, 0, 'Mumbai'),
#   Text(2, 0, 'Bangalore'),
#   Text(3, 0, 'Pune'),
#   Text(4, 0, 'New Delhi')])

# %% [markdown]
# ## Customer Preference Analysis:

# %% [markdown]
# #### Analyze the types of cuisines that are popular in different regions.

# %%
cuisines_region = df_2.groupby('cuisines')['city'].size().sort_values(ascending=False)
top_cuisines = cuisines_region.head(10)
print(top_cuisines)
# Plotting bar graph
plt.figure(figsize=(8,6))
plt.bar(top_cuisines.index,top_cuisines.values)
plt.title('Top 10 Cuisines across different Regions')
plt.xlabel('Cuisines')
plt.ylabel('Frequency')
plt.xticks(rotation=90)
plt.show()
# Out:
# cuisines
# North Indian             4587
# Fast Food                2137
# North Indian, Chinese    1720
# Bakery                   1618
# South Indian             1600
# Street Food              1221
# Cafe                     1180
# Mithai                   1032
# Desserts                  950
# Bakery, Desserts          872
# Name: city, dtype: int64

# %% [markdown]
# #### Examine the relationship between restaurant ratings, price range, and popularity.

# %%
# Plotting the correlation matrix to determine relationship
correlation = df_2[['votes','aggregate_rating','price_range']].corr()
plt.figure(figsize=(8,6))
sns.heatmap(correlation,annot=True,cmap='coolwarm',fmt='.2f')
plt.title('Correlation Matrix for Votes, aggregate_rating, and price_range')
plt.show()

# %%
# for distribution of restaurants by aggregate rating 
restaurants_rating = df_2.groupby('name')['aggregate_rating'].mean().sort_values(ascending=False)
top_restaurants = restaurants_rating.head(10)
print(top_restaurants)
#plotting barcharts
plt.figure(figsize=(8,6))
plt.bar(top_restaurants.index,top_restaurants.values)
plt.title('Distribution of Top 10 Restaurant and Aggregate Rating')
plt.xlabel('Restaurant City')
plt.ylabel('Aggregate Rating')
plt.xticks(rotation=90)
plt.show()
# Out:
# name
# Indish Lounge                      4.9
# Purple Martini                     4.9
# ARK 2.0 - Courtyard By Marriott    4.9
# Buttercupp                         4.9
# Milap's Punjabi Hotel              4.9
# Villa Maya Heritage Restaurant     4.9
# Conçu                              4.9
# Cafe Paashh                        4.9
# Pabbas                             4.9
# Sahib’s Barbeque by Ohri’s         4.9
# Name: aggregate_rating, dtype: float64

# %%
#Plotting Distribution of Rating by Average Price Range.
rating_range = df_2.groupby('price_range')['aggregate_rating'].mean()
print(rating_range)
# Plotting barcharts
plt.figure(figsize=(8,6))
colors=['red','blue','green','brown']
plt.bar(rating_range.index,rating_range.values,color=colors)
plt.title('Distribution of Average Rating accross Price Range')
plt.xlabel('Price Range')
plt.ylabel('Average Rating')
price_labels=['Low','Moderate','Expensive','Very Expensive']
plt.xticks(rating_range.index)
plt.show()
# Out:
# price_range
# 1    2.669837
# 2    3.281592
# 3    3.577653
# 4    3.701439
# Name: aggregate_rating, dtype: float64

# %% [markdown]
# ## Competitive Analysis

# %%
#Finding major competitors in each region based on cuisine, pricing, and ratings.
major_competitors = df_2.loc[df['cuisines'] != 'Not Available', ['city','cuisines','average_cost_for_two','aggregate_rating']]
duplicate_cities = major_competitors.drop_duplicates(subset='city')
duplicate_cities.nlargest(20,'aggregate_rating')
# Out:
#                 city                                           cuisines  \
# 15114       Amritsar                                 Fast Food, Italian
# 19630      Bangalore  Continental, North Indian, Chinese, European, ...
# 27257   Bhubaneshwar                                 Tex-Mex, Fast Food
# 53884      New Delhi                                              Asian
# 129079     Mangalore          Ice Cream, Desserts, Beverages, Fast Food
# 134885         Thane  Modern Indian, North Indian, Chinese, Momos, A...
# 151290        Nashik                       Continental, Indian, Chinese
# 173048        Rajkot  North Indian, Gujarati, South Indian, Continental
# 5936           Ajmer  Continental, Beverages, South Indian, Fast Foo...
# 11147      Allahabad                                       North Indian
# 24601         Bhopal  Street Food, South Indian, Fast Food, Desserts...
# 33460        Chennai  North Indian, European, Mediterranean, Contine...
# ...
